# %% [markdown]
# **Importing the Dependencies**

# %%
import sys
# !{sys.executable} -m pip install hyperopt
# Out:
# Collecting hyperopt
#   Downloading hyperopt-0.2.7-py2.py3-none-any.whl (1.6 MB)
#      ---------------------------------------- 1.6/1.6 MB 10.1 MB/s eta 0:00:00
# Requirement already satisfied: scipy in d:\apps\anaconda\anaconda\envs\my-conda-env\lib\site-packages (from hyperopt) (1.9.0)
# Requirement already satisfied: tqdm in d:\apps\anaconda\anaconda\envs\my-conda-env\lib\site-packages (from hyperopt) (4.64.0)
# Requirement already satisfied: six in d:\apps\anaconda\anaconda\envs\my-conda-env\lib\site-packages (from hyperopt) (1.16.0)
# Collecting networkx>=2.2
#   Downloading networkx-2.8.7-py3-none-any.whl (2.0 MB)
#      ---------------------------------------- 2.0/2.0 MB 16.1 MB/s eta 0:00:00
# Collecting cloudpickle
#   Downloading cloudpickle-2.2.0-py3-none-any.whl (25 kB)
# Requirement already satisfied: numpy in d:\apps\anaconda\anaconda\envs\my-conda-env\lib\site-packages (from hyperopt) (1.23.2)
# Collecting future
#   Using cached future-0.18.2.tar.gz (829 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Collecting py4j
#   Downloading py4j-0.10.9.7-py2.py3-none-any.whl (200 kB)
#      ------------------------------------- 200.5/200.5 kB 11.9 MB/s eta 0:00:00
# Requirement already satisfied: colorama in d:\apps\anaconda\anaconda\envs\my-conda-env\lib\site-packages (from tqdm->hyperopt) (0.4.5)
# Building wheels for collected packages: future
#   Building wheel for future (setup.py): started
#   Building wheel for future (setup.py): finished with status 'done'
#   Created wheel for future: filename=future-0.18.2-py3-none-any.whl size=491070 sha256=0a4cd448a6eeb91b8ff3fe3d9c1dd9a3f034450a9cea577030c3025debd1a63b
#   Stored in directory: c:\users\khs supriya\appdata\local\pip\cache\wheels\22\73\06\557dc4f4ef68179b9d763930d6eec26b88ed7c389b19588a1c
# Successfully built future
# Installing collected packages: py4j, networkx, future, cloudpickle, hyperopt
# Successfully installed cloudpickle-2.2.0 future-0.18.2 hyperopt-0.2.7 networkx-2.8.7 py4j-0.10.9.7

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import textwrap
import warnings
warnings.filterwarnings('ignore')
from tabulate import tabulate
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.stem import WordNetLemmatizer
from nltk import pos_tag
from nltk.corpus import wordnet
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.model_selection import train_test_split, cross_val_score, GridSearchCV
from sklearn.naive_bayes import MultinomialNB
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score
from sklearn.ensemble import StackingClassifier
from sklearn.linear_model import LogisticRegression

# %% [markdown]
# **Load the dataset**

# %%
data = pd.read_csv('train.csv')
actual_data = pd.read_csv('train.csv')

# %%
data.shape
# Out:
# (20800, 5)

# %%
data.head()
# Out:
#    id                                              title              author  \
# 0   0  House Dem Aide: We Didn’t Even See Comey’s Let...       Darrell Lucus
# 1   1  FLYNN: Hillary Clinton, Big Woman on Campus - ...     Daniel J. Flynn
# 2   2                  Why the Truth Might Get You Fired  Consortiumnews.com
# 3   3  15 Civilians Killed In Single US Airstrike Hav...     Jessica Purkiss
# 4   4  Iranian woman jailed for fictional unpublished...      Howard Portnoy
#
#                                                 text  label
# 0  House Dem Aide: We Didn’t Even See Comey’s Let...      1
# 1  Ever get the feeling your life circles the rou...      0
# 2  Why the Truth Might Get You Fired October 29, ...      1
# 3  Videos 15 Civilians Killed In Single US Airstr...      1
# 4  Print \nAn Iranian woman has been sentenced to...      1

# %% [markdown]
# # Preprocessing

# %% [markdown]
# **Remove NULL values**

# %%
data.isnull().sum()
# Out:
# id           0
# title      558
# author    1957
# text        39
# label        0
# dtype: int64

# %%
data.dropna(inplace=True)

# %%
data.isnull().sum()
# Out:
# id        0
# title     0
# author    0
# text      0
# label     0
# dtype: int64

# %% [markdown]
# **Remove unwanted columns**

# %%
data.drop(columns=['id'], inplace=True)

# %% [markdown]
# # Exploratory Data Analysis

# %%
from tabulate import tabulate

alldata = ['All', data['title'].apply(len).mean(), data['title'].apply(len).min(), data['title'].apply(len).max()]
realdata = ['Real', data['title'][data['label'] == 0].apply(len).mean(), data['title'][data['label'] == 0].apply(len).min(), data['title'][data['label'] == 0].apply(len).max()]
fakedata = ['Fake', data['title'][data['label'] == 1].apply(len).mean(), data['title'][data['label'] == 1].apply(len).min(), data['title'][data['label'] == 1].apply(len).max()]

table = [['Label', 'Mean Length', 'Min Length', 'Max Length'], alldata, realdata, fakedata]
print(tabulate(table, headers='firstrow', tablefmt='fancy_grid'))
# Out:
# ╒═════════╤═══════════════╤══════════════╤══════════════╕
# │ Label   │   Mean Length │   Min Length │   Max Length │
# ╞═════════╪═══════════════╪══════════════╪══════════════╡
# │ All     │       74.7023 │            3 │          456 │
# ├─────────┼───────────────┼──────────────┼──────────────┤
# │ Real    │       79.6142 │           22 │          175 │
# ├─────────┼───────────────┼──────────────┼──────────────┤
# │ Fake    │       68.2798 │            3 │          456 │
# ╘═════════╧═══════════════╧══════════════╧══════════════╛

# %%
plt.title('Length of Titles vs Frequency')
plt.xlabel('Length of Title')
plt.ylabel('Frequency')
plt.hist(data['title'].apply(len), color='orange')
plt.show()

# %%
fig = plt.figure()
ax = fig.add_subplot(111)
ax.set_xticklabels(['title'])
plt.boxplot(data['title'].apply(len))
plt.show()

# %%
from collections import Counter

c = Counter(data['author'][data['label'] == 1]).most_common(8)
print(c)

x, y = zip(*c)

plt.figure(figsize=(20, 8))
plt.title('Top Authors with Fake News')
plt.xlabel('Name of Author')
plt.ylabel('No.of fake texts')
plt.bar(x, y, color=(0.2, 0.4, 0.6, 0.6))
plt.show()
# Out:
# [('admin', 193), ('Pakalert', 86), ('Eddy Lavine', 85), ('Starkman', 84), ('Alex Ansary', 82), ('Gillian', 82), ('Editor', 81), ('noreply@blogger.com (Alexander Light)', 80)]

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt


plt.figure(figsize=(13, 7))


# Fake News Word Cloud

text=(' '.join(data['title'][data['label'] == 1]))
wordcloud = WordCloud(width=480, height=480, margin=0).generate(text)

plt.subplot(1, 2, 1)
plt.title('Fake News Title Word Cloud')
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")


# Real News Word Cloud

text=(' '.join(data['title'][data['label'] == 0]))
wordcloud = WordCloud(width=480, height=480, margin=0).generate(text)

plt.subplot(1, 2, 2)
plt.title('Real News Title Word Cloud')
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.show()

# %%
fake_trump_len = len(data[data['text'].str.contains('trump')][data['label'] == 1])
real_trump_len = len(data[data['text'].str.contains('trump')][data['label'] == 0])

plt.title('Text with word Trump')
plt.xlabel('Type')
plt.ylabel('No.of texts')
plt.bar(['Real', 'Fake'], [real_trump_len, fake_trump_len], color=['coral', 'cornflowerblue'])
plt.show()

# %% [markdown]
# **Combine necessary columns**

# %%
data['content'] = data['author'] + '\n' + data['title'] + '\n' + data['text']
data.drop(columns = ['title', 'author', 'text'], inplace=True)

# %% [markdown]
# # Tokenization
# It is the process of dividing a text into smaller units (each word will be an index in an array)

# %%
data['content'] = data.apply(lambda row: word_tokenize(row['content']), axis=1)
# data.iloc[0]['content']

# %% [markdown]
# # Lemmatization
# It removes the endings of the word to the root word. It reduces the word children to a child.

# %%
lemmatizer = WordNetLemmatizer()

def pos_tag_to_wordnet_tag(nltk_tag):
    if nltk_tag.startswith('J'):
        return wordnet.ADJ
    elif nltk_tag.startswith('V'):
        return wordnet.VERB
    elif nltk_tag.startswith('N'):
        return wordnet.NOUN
    elif nltk_tag.startswith('R'):
        return wordnet.ADV
    else:          
        return None

def lemmatize_tokens(tokens):
    nltk_tagged = pos_tag(tokens)  
    wordnet_tagged = map(lambda x: (x[0], pos_tag_to_wordnet_tag(x[1])), nltk_tagged)
    lemmatized_tokens = []
    
    for word, tag in wordnet_tagged:
        if tag is None:
            lemmatized_tokens.append(word)
        else:        
            lemmatized_tokens.append(lemmatizer.lemmatize(word, tag))
    return lemmatized_tokens


data['content'] = data['content'].apply(lemmatize_tokens)
# data.iloc[0]['content']

# %% [markdown]
# # Stop words Removal
# Words like the and for will be eliminated from our dataset because they take too much room.

# %%
stops = stopwords.words('english')
data['content'] = data['content'].apply(lambda x: [i for i in x if i not in stops and len(i) > 1])
data.iloc[0]['content']
# Out:
# ['Darrell',
#  'Lucus',
#  'House',
#  'Dem',
#  'Aide',
#  'We',
#  'Didn',
#  'Even',
#  'See',
#  'Comey',
#  'Letter',
#  'Until',
#  'Jason',
#  'Chaffetz',
#  'Tweeted',
#  'It',
#  'House',
#  'Dem',
#  'Aide',
#  'We',
#  'Didn',
#  'Even',
#  'See',
#  'Comey',
#  'Letter',
#  'Until',
#  'Jason',
#  'Chaffetz',
#  'Tweeted',
#  'It',
#  'By',
#  'Darrell',
#  'Lucus',
#  'October',
#  '30',
#  '2016',
#  'Subscribe',
#  'Jason',
#  'Chaffetz',
#  'stump',
#  'American',
#  'Fork',
#  'Utah',
#  'image',
#  'courtesy',
#  'Michael',
#  'Jolley',
#  'available',
#  'Creative',
#  'Commons-BY',
#  'license',
#  'With',
#  'apology',
#  'Keith',
#  'Olbermann',
#  'doubt',
#  'Worst',
#  'Person',
#  'The',
#  'World',
#  'week–FBI',
#  'Director',
#  'James',
#  'Comey',
#  'But',
#  'accord',
#  'House',
#  'Democratic',
#  'aide',
#  'look',
#  'like',
#  'also',
#  'know',
#  'second-worst',
#  'person',
#  'well',
#  'It',
#  'turn',
#  'Comey',
#  'send',
#  'now-infamous',
#  'letter',
#  'announce',
#  'FBI',
#  'look',
#  'email',
#  'may',
#  'relate',
#  'Hillary',
#  'Clinton',
#  'email',
#  'server',
#  'ranking',
#  'Democrats',
#  'relevant',
#  'committee',
#  'hear',
#  'Comey',
#  'They',
#  'find',
#  'via',
#  'tweet',
#  'one',
#  'Republican',
#  'committee',
#  'chairman',
#  'As',
#  'know',
#  'Comey',
#  'notify',
#  'Republican',
#  'chairman',
#  'Democratic',
#  'rank',
#  'member',
#  'House',
#  'Intelligence',
#  'Judiciary',
#  'Oversight',
#  'committee',
#  'agency',
#  'review',
#  'email',
#  'recently',
#  'discover',
#  'order',
#  'see',
#  'contain',
#  'classified',
#  'information',
#  'Not',
#  'long',
#  'letter',
#  'go',
#  'Oversight',
#  'Committee',
#  'Chairman',
#  'Jason',
#  'Chaffetz',
#  'set',
#  'political',
#  'world',
#  'ablaze',
#  'tweet',
#  'FBI',
#  'Dir',
#  'inform',
#  '``',
#  'The',
#  'FBI',
#  'learn',
#  'existence',
#  'email',
#  'appear',
#  'pertinent',
#  'investigation',
#  "''",
#  'Case',
#  'reopen',
#  'Jason',
#  'Chaffetz',
#  'jasoninthehouse',
#  'October',
#  '28',
#  '2016',
#  'Of',
#  'course',
#  'know',
#  'case',
#  'Comey',
#  'actually',
#  'say',
#  'review',
#  'email',
#  'light',
#  'unrelated',
#  'case',
#  '–which',
#  'know',
#  'Anthony',
#  'Weiner',
#  'sexting',
#  'teenager',
#  'But',
#  'apparently',
#  'little',
#  'thing',
#  'fact',
#  'matter',
#  'Chaffetz',
#  'The',
#  'Utah',
#  'Republican',
#  'already',
#  'vow',
#  'initiate',
#  'raft',
#  'investigation',
#  'Hillary',
#  'wins–at',
#  'least',
#  'two',
#  'year',
#  'worth',
#  'possibly',
#  'entire',
#  'term',
#  'worth',
#  'Apparently',
#  'Chaffetz',
#  'think',
#  'FBI',
#  'already',
#  'work',
#  'him–resulting',
#  'tweet',
#  'briefly',
#  'roil',
#  'nation',
#  'cooler',
#  'head',
#  'realize',
#  'dud',
#  'But',
#  'accord',
#  'senior',
#  'House',
#  'Democratic',
#  'aide',
#  'misread',
#  'letter',
#  'may',
#  'least',
#  'Chaffetz',
#  'sin',
#  'That',
#  'aide',
#  'tell',
#  'Shareblue',
#  'bos',
#  'Democrats',
#  'even',
#  'know',
#  'Comey',
#  'letter',
#  'time–and',
#  'find',
#  'check',
#  'Twitter',
#  'Democratic',
#  'Ranking',
#  'Members',
#  'relevant',
#  'committee',
#  'receive',
#  'Comey',
#  'letter',
#  'Republican',
#  'Chairmen',
#  'In',
#  'fact',
#  'Democratic',
#  'Ranking',
#  'Members',
#  'receive',
#  'Chairman',
#  'Oversight',
#  'Government',
#  'Reform',
#  'Committee',
#  'Jason',
#  'Chaffetz',
#  'tweet',
#  'make',
#  'public.',
#  'So',
#  'let',
#  'see',
#  'get',
#  'right',
#  'The',
#  'FBI',
#  'director',
#  'tell',
#  'Chaffetz',
#  'GOP',
#  'committee',
#  'chairman',
#  'major',
#  'development',
#  'potentially',
#  'politically',
#  'explosive',
#  'investigation',
#  'neither',
#  'Chaffetz',
#  'colleague',
#  'courtesy',
#  'let',
#  'Democratic',
#  'counterpart',
#  'know',
#  'Instead',
#  'accord',
#  'aide',
#  'make',
#  'find',
#  'Twitter',
#  'There',
#  'already',
#  'talk',
#  'Daily',
#  'Kos',
#  'Comey',
#  'provide',
#  'advance',
#  'notice',
#  'letter',
#  'Chaffetz',
#  'Republicans',
#  'give',
#  'time',
#  'turn',
#  'spin',
#  'machine',
#  'That',
#  'may',
#  'make',
#  'good',
#  'theater',
#  'nothing',
#  'far',
#  'even',
#  'suggest',
#  'case',
#  'After',
#  'nothing',
#  'far',
#  'suggest',
#  'Comey',
#  'anything',
#  'grossly',
#  'incompetent',
#  'tone-deaf',
#  'What',
#  'suggest',
#  'however',
#  'Chaffetz',
#  'act',
#  'way',
#  'make',
#  'Dan',
#  'Burton',
#  'Darrell',
#  'Issa',
#  'look',
#  'like',
#  'model',
#  'responsibility',
#  'bipartisanship',
#  'He',
#  'even',
#  'decency',
#  'notify',
#  'ranking',
#  'member',
#  'Elijah',
#  'Cummings',
#  'something',
#  'explosive',
#  'If',
#  'trample',
#  'basic',
#  'standard',
#  'fairness',
#  'know',
#  'Granted',
#  'likely',
#  'Chaffetz',
#  'answer',
#  'He',
#  'sit',
#  'ridiculously',
#  'Republican',
#  'district',
#  'anchor',
#  'Provo',
#  'Orem',
#  'Cook',
#  'Partisan',
#  'Voting',
#  'Index',
#  'R+25',
#  'give',
#  'Mitt',
#  'Romney',
#  'punish',
#  '78',
#  'percent',
#  'vote',
#  '2012',
#  'Moreover',
#  'Republican',
#  'House',
#  'leadership',
#  'give',
#  'full',
#  'support',
#  'Chaffetz',
#  'plan',
#  'fish',
#  'expedition',
#  'But',
#  'mean',
#  'turn',
#  'hot',
#  'light',
#  'After',
#  'textbook',
#  'example',
#  'House',
#  'become',
#  'Republican',
#  'control',
#  'And',
#  'also',
#  'Second',
#  'Worst',
#  'Person',
#  'World',
#  'About',
#  'Darrell',
#  'Lucus',
#  'Darrell',
#  '30-something',
#  'graduate',
#  'University',
#  'North',
#  'Carolina',
#  'consider',
#  'journalist',
#  'old',
#  'school',
#  'An',
#  'attempt',
#  'turn',
#  'member',
#  'religious',
#  'right',
#  'college',
#  'succeed',
#  'turn',
#  'religious',
#  'right',
#  "'s",
#  'bad',
#  'nightmare',
#  '--',
#  'charismatic',
#  'Christian',
#  'unapologetic',
#  'liberal',
#  'His',
#  'desire',
#  'stand',
#  'scar',
#  'silence',
#  'increase',
#  'survive',
#  'abusive',
#  'three-year',
#  'marriage',
#  'You',
#  'may',
#  'know',
#  'Daily',
#  'Kos',
#  'Christian',
#  'Dem',
#  'NC',
#  'Follow',
#  'Twitter',
#  'DarrellLucus',
#  'connect',
#  'Facebook',
#  'Click',
#  'buy',
#  'Darrell',
#  'Mello',
#  'Yello',
#  'Connect']

# %%
data['content'] = data['content'].apply(lambda x: ' '.join(x))

actual = actual_data.iloc[1]['text'][:535]
processed = data.iloc[1]['content'][65:464]

def print_side_by_side(a, b, size=50, space=4):
    print("Raw Text".ljust(size) + " " * (space // 2) + '|' + " " * (space // 2) + "Processed Text")
    print("="*(2 * size + space))
    while a or b:
        print(a[:size].ljust(size) + " " * (space // 2) + '|' + " " * (space // 2) + b[:size])
        a = a[size:]
        b = b[size:]

print_side_by_side(actual,processed)
# Out:
# Raw Text                                            |  Processed Text
# ========================================================================================================
# Ever get the feeling your life circles the roundab  |  Ever get feeling life circle roundabout rather hea
# out rather than heads in a straight line toward th  |  d straight line toward intend destination Hillary
# e intended destination? [Hillary Clinton remains t  |  Clinton remain big woman campus leafy liberal Well
# he big woman on campus in leafy, liberal Wellesley  |  esley Massachusetts Everywhere else vote likely in
# , Massachusetts. Everywhere else votes her most li  |  auguration dress remainder day way Miss Havisham f
# kely to don her inauguration dress for the remaind  |  orever wear wed dress Speaking Great Expectations
# er of her days the way Miss Havisham forever wore   |  Hillary Rodham overflow 48 year ago first address
# that wedding dress.  Speaking of Great Expectation  |  Wellesley graduating class The president college
# s, Hillary Rodham overflowed with them 48 years ag  |
# o when she first addressed a Wellesley graduating   |
# class. The president of the college                 |

# %% [markdown]
# # Train Test Split

# %%
train_X, test_X, train_Y, test_Y = train_test_split(data['content'], data['label'], test_size=0.3)

# %% [markdown]
# # Word Vectorization: TFIDF
#
# - **Term Frequency:** This summarizes how often a given word appears within a document. <br/>
#     TF = (#occurences of the word) / (#words in the doc)
# - **Inverse Document Frequency:** This down scales words that appear a lot across documents. <br/>
#     IDF = log((#documents) / (#documents containing the given word))
#
#     TFIDF = TF * IDF
#
# Without going into the math, TF-IDF are word frequency scores that try to highlight words that are more interesting, e.g. frequent in a document but not across documents.

# %%
tfidf_vect = TfidfVectorizer(max_features=5000)

tfidf_vect.fit(data['content'])

train_X_Tfidf = tfidf_vect.transform(train_X)
test_X_Tfidf = tfidf_vect.transform(test_X)


print(tfidf_vect.vocabulary_)
# Out:
# {'house': 2203, 'dem': 1276, 'aide': 244, 'we': 4855, 'even': 1651, 'see': 3993, 'comey': 954, 'letter': 2636, 'until': 4725, 'jason': 2450, 'it': 2433, 'by': 725, 'october': 3122, '30': 69, '2016': 53, 'subscribe': 4328, 'american': 302, 'utah': 4748, 'image': 2259, 'courtesy': 1133, 'michael': 2861, 'available': 472, 'creative': 1147, 'license': 2650, 'with': 4930, 'apology': 355, 'keith': 2520, 'doubt': 1440, 'person': 3336, 'the': 4494, 'world': 4949, 'week': 4868, 'fbi': 1774, 'director': 1370, 'james': 2443, 'but': 720, 'accord': 151, 'democratic': 1280, 'look': 2691, 'like': 2658, 'also': 286, 'know': 2548, 'second': 3984, 'well': 4878, 'turn': 4655, 'send': 4009, 'now': 3085, 'infamous': 2318, 'announce': 330, 'email': 1546, 'may': 2799, 'relate': 3736, 'hillary': 2155, 'clinton': 904, 'server': 4023, 'ranking': 3647, 'democrats': 1281, 'relevant': 3744, 'committee': 971, 'hear': 2125, 'they': 4507, 'find': 1820, 'via': 4781, 'tweet': 4658, 'one': 3154, 'republican': 3783, 'chairman': 812, 'as': 408, 'notify': 3079, 'rank': 3646, 'member': 2830, 'intelligence': 2369, 'judiciary': 2496, 'oversight': 3224, 'agency': 229, 'review': 3835, 'recently': 3685, 'discover': 1382, 'order': 3182, 'contain': 1064, 'classified': 890, 'information': 2325, 'not': 3073, 'long': 2687, 'go': 2000, 'set': 4028, 'political': 3416, 'inform': 2324, 'learn': 2606, 'existence': 1693, 'appear': 360, 'investigation': 2400, 'case': 777, 'reopen': 3765, '28': 67, 'of': 3125, 'course': 1131, 'actually': 176, 'say': 3944, 'light': 2657, 'which': 4891, 'anthony': 339, 'weiner': 4874, 'teenager': 4458, 'apparently': 358, 'little': 2671, 'thing': 4510, 'fact': 1737, 'matter': 2794, 'already': 285, 'vow': 4820, 'initiate': 2332, 'at': 437, 'least': 2609, 'two': 4664, 'year': 4970, 'worth': 4955, 'possibly': 3449, 'entire': 1597, 'term': 4476, 'think': 4512, 'work': 4944, 'him': 2156, 'briefly': 678, 'nation': 2992, 'head': 2117, 'realize': 3674, 'senior': 4010, 'sin': 4103, 'that': 4493, 'tell': 4463, 'bos': 641, 'time': 4541, 'and': 316, 'check': 839, 'twitter': 4663, 'members': 2831, 'receive': 3683, 'in': 2283, 'government': 2018, 'reform': 3708, 'make': 2736, 'public': 3585, 'so': 4151, 'let': 2635, 'get': 1980, 'right': 3854, 'gop': 2011, 'major': 2734, 'development': 1338, 'potentially': 3457, 'politically': 3417, 'explosive': 1714, 'neither': 3022, 'colleague': 934, 'counterpart': 1123, 'instead': 2355, 'there': 4503, 'talk': 4432, 'daily': 1198, 'provide': 3576, 'advance': 197, 'notice': 3078, 'republicans': 3784, 'give': 1989, 'spin': 4219, 'machine': 2720, 'good': 2009, 'theater': 4495, 'nothing': 3077, 'far': 1757, 'suggest': 4351, 'after': 222, 'anything': 348, 'tone': 4560, 'what': 4884, 'however': 2209, 'act': 166, 'way': 4854, 'dan': 1205, 'model': 2913, 'responsibility': 3809, 'he': 2116, 'something': 4172, 'if': 2243, 'basic': 519, 'standard': 4253, 'likely': 2659, 'answer': 337, 'sit': 4113, 'district': 1407, 'anchor': 314, 'cook': 1092, 'partisan': 3278, 'voting': 4819, 'index': 2303, '25': 63, 'mitt': 2905, 'romney': 3881, 'punish': 3596, 'percent': 3321, 'vote': 4816, '2012': 49, 'moreover': 2935, 'leadership': 2598, 'full': 1932, 'support': 4366, 'plan': 3385, 'fish': 1832, 'mean': 2808, 'hot': 2200, 'example': 1672, 'become': 539, 'control': 1081, 'about': 131, 'graduate': 2024, 'university': 4715, 'north': 3069, 'carolina': 771, 'consider': 1044, 'journalist': 2488, 'old': 3147, 'school': 3958, 'an': 310, 'attempt': 446, 'religious': 3748, 'college': 938, 'succeed': 4336, 'bad': 488, 'nightmare': 3049, 'christian': 860, 'liberal': 2642, 'his': 2159, 'desire': 1316, 'stand': 4252, 'scar': 3950, 'silence': 4093, 'increase': 2295, 'survive': 4389, 'three': 4527, 'marriage': 2774, 'you': 4981, 'follow': 1859, 'connect': 1034, 'facebook': 1734, 'click': 897, 'buy': 722, 'daniel': 1209, 'flynn': 1856, 'big': 584, 'woman': 4937, 'campus': 742, 'breitbart': 671, 'ever': 1655, 'feeling': 1787, 'life': 2653, 'circle': 872, 'rather': 3658,  ...

# %% [markdown]
# # Naive Bayes

# %%
Naive = MultinomialNB()

# %%
best = cross_val_score(Naive, train_X_Tfidf, train_Y).mean()
best_clf = Naive
print("Cross Validation Score -> ", best)

from hyperopt import hp, tpe, fmin,STATUS_OK,Trials

def accuracy_model(params):
    clf = MultinomialNB(**params)
    return (cross_val_score(clf, train_X_Tfidf, train_Y).mean(), clf)

param_space = {
    'alpha': hp.choice('alpha', np.linspace(0.5, 1.5, 6)),
    'fit_prior': hp.choice('fit_prior', [True, False])
}

best_params = []
def f(params):
    global best, best_clf, best_params
    acc, clf = accuracy_model(params)
    if acc > best:
        best = acc
        best_clf = clf
        best_params = params
    return {'loss': -acc, 'status': STATUS_OK}

fmin(f, param_space , algo=tpe.suggest, max_evals=500)

Naive = best_clf
print('New best:', best, best_params)
# Out:
# Cross Validation Score ->  0.9158532690992576
# 100%|█████████████████████████████████████████████| 500/500 [02:14<00:00,  3.73trial/s, best loss: -0.9232755409828058]
# New best: 0.9232755409828058 {'alpha': 1.1, 'fit_prior': False}

# %%
Naive.fit(train_X_Tfidf, train_Y)
# Out:
# MultinomialNB(alpha=1.1, fit_prior=False)

# %%
# predict the labels on validation dataset
predictions_NB_test = Naive.predict(test_X_Tfidf)
predictions_NB_train = Naive.predict(train_X_Tfidf)

# Use accuracy_score function to get the accuracy
accuracy_NB_test = accuracy_score(predictions_NB_test, test_Y) * 100
accuracy_NB_train = accuracy_score(predictions_NB_train, train_Y) * 100

print("Naive Bayes Accuracy Score -> ", accuracy_score(predictions_NB_test, test_Y)*100)
# Out:
# Naive Bayes Accuracy Score ->  91.54210718191761

# %% [markdown]
# # SVM

# %%
SVM = SVC(kernel='linear', gamma='auto')

# %%
best = cross_val_score(SVM, train_X_Tfidf, train_Y).mean()
best_clf = SVM
print("Cross Validation Score -> ", best)

from hyperopt import hp, tpe, fmin,STATUS_OK,Trials

def accuracy_model(params):
    clf = SVC(kernel='linear', gamma='auto', **params)
    return (cross_val_score(clf, train_X_Tfidf, train_Y).mean(), clf)

param_space = {
    'C': hp.choice('C', np.linspace(0.1, 1000, 4))
}

best_params = []
def f(params):
    global best, best_clf, best_params
    acc, clf = accuracy_model(params)
    if acc > best:
        best = acc
        best_clf = clf
        best_params = params
    return {'loss': -acc, 'status': STATUS_OK}

fmin(f, param_space , algo=tpe.suggest, max_evals=1)

SVM = best_clf
print('New best:', best, best_params)
# Out:
# Cross Validation Score ->  0.9682788992282141
# 100%|█████████████████████████████████████████████████| 1/1 [06:20<00:00, 380.18s/trial, best loss: -0.962965880226651]
# New best: 0.9682788992282141 []

# %%
SVM = SVC(C=1.0, kernel='linear', gamma='auto')

# fit the training dataset on the classifier
SVM.fit(train_X_Tfidf, train_Y)

# predict the labels on validation dataset
predictions_SVM_test = SVM.predict(test_X_Tfidf)
predictions_SVM_train = SVM.predict(train_X_Tfidf)

# Use accuracy_score function to get the accuracy
accuracy_SVM_test = accuracy_score(predictions_SVM_test, test_Y) * 100
accuracy_SVM_train = accuracy_score(predictions_SVM_train, train_Y) * 100

print("SVM Accuracy Score -> ",accuracy_score(predictions_SVM_test, test_Y)*100)
# Out:
# SVM Accuracy Score ->  56.1246810061976

# %%
print("Cross Validation Score -> ", cross_val_score(SVM, train_X, train_Y))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [44], in <cell line: 1>()
# ----> 1 print("Cross Validation Score -> ", cross_val_score(SVM, train_X, train_Y))
#
# File D:\apps\Anaconda\Anaconda\envs\my-conda-env\lib\site-packages\sklearn\model_selection\_validation.py:515, in cross_val_score(estimator, X, y, groups, scoring, cv, n_jobs, verbose, fit_params, pre_dispatch, error_score)
#     512 # To ensure multimetric format is not supported
#     513 scorer = check_scoring(estimator, scoring=scoring)
# --> 515 cv_results = cross_validate(
#     516     estimator=estimator,
#     517     X=X,
#     518     y=y,
#     519     groups=groups,
#     520     scoring={"score": scorer},
#     521     cv=cv,
#     522     n_jobs=n_jobs,
#     523     verbose=verbose,
#     524     fit_params=fit_params,
#     525     pre_dispatch=pre_dispatch,
#     526     error_score=error_score,
#     527 )
#     528 return cv_results["test_score"]
#
# File D:\apps\Anaconda\Anaconda\envs\my-conda-env\lib\site-packages\sklearn\model_selection\_validation.py:285, in cross_validate(estimator, X, y, groups, scoring, cv, n_jobs, verbose, fit_params, pre_dispatch, return_train_score, return_estimator, error_score)
#     265 parallel = Parallel(n_jobs=n_jobs, verbose=verbose, pre_dispatch=pre_dispatch)
#     266 results = parallel(
#     267     delayed(_fit_and_score)(
#     268         clone(estimator),
#    (...)
#     282     for train, test in cv.split(X, y, groups)
#     283 )
# --> 285 _warn_or_raise_about_fit_failures(results, error_score)
#     287 # For callabe scoring, the return type is only know after calling. If the
#     288 # return type is a dictionary, the error scores can now be inserted with
#     289 # the correct key.
#     290 if callable(scoring):
#
# File D:\apps\Anaconda\Anaconda\envs\my-conda-env\lib\site-packages\sklearn\model_selection\_validation.py:367, in _warn_or_raise_about_fit_failures(results, error_score)
#     360 if num_failed_fits == num_fits:
#     361     all_fits_failed_message = (
#     362         f"\nAll the {num_fits} fits failed.\n"
#     363         "It is very likely that your model is misconfigured.\n"
#     364         "You can try to debug the error by setting error_score='raise'.\n\n"
#     365         f"Below are more details about the failures:\n{fit_errors_summary}"
#     366     )
# --> 367     raise ValueError(all_fits_failed_message)
#     369 else:
#     370     some_fits_failed_message = (
#     371         f"\n{num_failed_fits} fits failed out of a total of {num_fits}.\n"
#     372         "The score on these train-test partitions for these parameters"
#    (...)
#     376         f"Below are more details about the failures:\n{fit_errors_summary}"
#     377     )
#
# ValueError:
# All the 5 fits failed.
# It is very likely that your model is misconfigured.
# You can try to debug the error by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 1 fits failed with the following error:
# Traceback (most recent call last):
#   File "D:\apps\Anaconda\Anaconda\envs\my-conda-env\lib\site-packages\sklearn\model_selection\_validation.py", line 686, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "D:\apps\Anaconda\Anaconda\envs\my-conda-env\lib\site-packages\sklearn\svm\_base.py", line 173, in fit
#     X, y = self._validate_data(
#   File "D:\apps\Anaconda\Anaconda\envs\my-conda-env\lib\site-packages\sklearn\base.py", line 596, in _validate_data
#     X, y = check_X_y(X, y, **check_params)
#   File "D:\apps\Anaconda\Anaconda\envs\my-conda-env\lib\site-packages\sklearn\utils\validation.py", line 1074, in check_X_y
#     X = check_array(
#   File "D:\apps\Anaconda\Anaconda\envs\my-conda-env\lib\site-packages\sklearn\utils\validation.py", line 856, in check_array
#     array = np.asarray(array, order=order, dtype=dtype)
#   File "D:\apps\Anaconda\Anaconda\envs\my-conda-env\lib\site-packages\pandas\core\series.py", line 872, in __array__
#     return np.asarray(self._values, dtype)
# ValueError: could not convert string to float: 'Europa-News Trump Possible Path Out Ukraine Crisis Consortiumnews Home News Ukraine Trump Possible Path Out Ukraine Crisis Consortiumnews Trump Possible Path Out Ukraine Crisis Consortiumnews Exclusive The U.S.-backed coup Ukraine 2014 spark New Cold War Russia President Trump could roll back tension creative strategy resolve Ukraine standoff write Jonathan Marshall By Jonathan Marshall If Donald Trump want make decisive constructive mark U.S. foreign policy early presidency good place start help end brutal war Ukraine claim 10,000 life President-elect Donald Trump The Obama administration help ignite war attempt yank Ukraine Russia orbit Western security economic sphere Working alongside European Union Washington fan mass street protest lead violent putsch Kiev elect government February 2014 Moscow respond annex depend point view reunify Russian-speaking Crimea also headquarters Moscow Black Sea Fleet back pro-Russia separatist eastern region Donetsk Luhansk Since two side fight bloody stalemate Besides kill thousand civilian war sink Ukraine economy foster rampant corruption U.S. E.U sanction drag Russia economy derailed cooperation Washington Moscow theater Rising tension NATO Russia greatly raise odds accidental military confrontation world two large nuclear power The best hope Ukraine renew East-West cooperation Minsk Protocol sign Ukrainian Russian European party capital Belarus Sept. 2014 The agreement provide ceasefire exchange prisoner framework political settlement base give Donetsk Luhansk region special status. That agreement break amid renew fighting party sign Minsk-2 Agreement Feb. 12 2015 It provide constitutional reform election two republic restoration Ukrainian sovereignty border But Kiev make serious move recognize special status breakaway region two side engage sporadic hostility ever since Final Words Presidents Obama Putin exchange may final desultory word subject Asia-Pacific Economic Cooperation summit Peru month Obama urge President Putin uphold Russia commitment Minsk agreement Russian spokesman say two men express regret possible make progress Ukraine. President Barack Obama meet President Vladimir Putin Russia sideline G20 Summit Regnum Carya Resort Antalya Turkey Sunday Nov. 15 2015 National Security Advisor Susan E. Rice listen left Official White House Photo Pete Souza As current foreign policy mess go however Ukrainian imbroglio may offer great opportunity rewarding cleanup Doing require side acknowledge fault find creative way save face Fortunately President-elect Trump create opening settlement reach Putin election campaign explicitly decline bash Russia annexation Crimea follow hastily arrange referendum official result show 96 percent voter favor leave Ukraine rejoin Russia There also small sign progress give hope limited demilitarization accord sign September lead mutual retreat Ukrainian army pro-Russia separatist small city eastern Ukraine The withdrawal verify observer Organization Security Cooperation Europe OSCE party Minsk accord Meanwhile Ukraine Germany France Russia work new roadmap strengthen ceasefire Conditions Peace In June 2015 interview Charlie Rose Putin lay clear reasonable condition make Minsk accord stick Ukraine anti-Russian President Petro Poroshenko speak Atlantic Council 2014 Photo credit Atlantic Council Today primarily need comply agreement reach Minsk At time would like draw attention partner fact unilaterally We keep hear thing repeat like mantra Russia influence southeast Ukraine We However impossible resolve problem influence southeast alone There influence current official authority Kiev something This road Western partner take Europe America Let us work together We believe resolve situation need implement Minsk agreement say The element political settlement key There several. The first one constitutional reform Minsk agreement say clearly provide autonomy say decentralization power The second thing law pass earl ...
#
# --------------------------------------------------------------------------------
# 4 fits failed with the following error:
# Traceback (most recent call last):
#   File "D:\apps\Anaconda\Anaconda\envs\my-conda-env\lib\site-packages\sklearn\model_selection\_validation.py", line 686, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "D:\apps\Anaconda\Anaconda\envs\my-conda-env\lib\site-packages\sklearn\svm\_base.py", line 173, in fit
#     X, y = self._validate_data(
#   File "D:\apps\Anaconda\Anaconda\envs\my-conda-env\lib\site-packages\sklearn\base.py", line 596, in _validate_data
#     X, y = check_X_y(X, y, **check_params)
#   File "D:\apps\Anaconda\Anaconda\envs\my-conda-env\lib\site-packages\sklearn\utils\validation.py", line 1074, in check_X_y
#     X = check_array(
#   File "D:\apps\Anaconda\Anaconda\envs\my-conda-env\lib\site-packages\sklearn\utils\validation.py", line 856, in check_array
#     array = np.asarray(array, order=order, dtype=dtype)
#   File "D:\apps\Anaconda\Anaconda\envs\my-conda-env\lib\site-packages\pandas\core\series.py", line 872, in __array__
#     return np.asarray(self._values, dtype)
# ValueError: could not convert string to float: 'Steph Yin For Some Arctic Plants Spring Arrives Almost Month Earlier The New York Times Every spring Arctic plant rely direct indirect cue environment like warmer weather long day shrink sea ice cover tell awaken winter slumber But climate warms plant get mixed signal rouse In new paper publish Biology Letters researcher detail finding study plant specie low Arctic region Greenland first green spring Timing vary plant plant one speedy sedge specie flowering grasslike herb stir full 26 day earlier decade ago The change correspond nearly entire growing season break record great shift spring emergence scientist observe Arctic Changes grow season associate diminish sea ice cover serve reminder loss may widespread effect life land say Jeffrey Kerby environmental study researcher Dartmouth College author study Shifting pattern plant growth may affect availability nutritious food herbivore example Dr. Kerby colleague find 2013 caribou calf die early year spring plant growth precede animal calve season Over difference early bloomer late bloomer widen long period plant bloom researcher find new study According Eric Post ecology professor University California Davis paper lead author transformation Arctic happen rapidly discernible researcher study ecology decade As climate scientist study start spring struggle answer question What spring say Heidi Steltzer professor Fort Lewis College author paper longer spring open potential gap point time would spring springlike event occur Would still spring'

# %% [markdown]
# # Decision Tree

# %%
Decision_tree = DecisionTreeClassifier()

# fit the training dataset on the classifier
Decision_tree.fit(train_X_Tfidf, train_Y)

# predict the labels on validation dataset
predictions_DT_test = Decision_tree.predict(test_X_Tfidf)
predictions_DT_train = Decision_tree.predict(train_X_Tfidf)

# Use accuracy_score function to get the accuracy
accuracy_DT_test = accuracy_score(predictions_DT_test, test_Y) * 100
accuracy_DT_train = accuracy_score(predictions_DT_train, train_Y) * 100

print("Decision Tree Accuracy Score -> ",accuracy_score(predictions_DT_test, test_Y)*100)
# Out:
# Decision Tree Accuracy Score ->  94.07582938388626

# %% [markdown]
# # Stacking Model
#
# - Base Models are Naive Bayes, SVM and Decision Tree
# - Meta Model is Logistic Regression
# - Meta Model uses the outputs from the different classifiers to predict the given row's label for its training

# %%
estimator_list = [
    ('nb', Naive),
    ('svc', SVM),
    ('dt', Decision_tree)]

# Build stack model
stack_model = StackingClassifier(
    estimators=estimator_list, final_estimator=LogisticRegression()
)

# fit the training dataset on the classifier
stack_model.fit(train_X_Tfidf, train_Y)

# predict the labels on validation dataset
predictions_stack_test = stack_model.predict(test_X_Tfidf)
predictions_stack_train = stack_model.predict(train_X_Tfidf)

# Use accuracy_score function to get the accuracy
accuracy_stack_test = accuracy_score(predictions_stack_test, test_Y) * 100
accuracy_stack_train = accuracy_score(predictions_stack_train, train_Y) * 100

print("Stacked Model Accuracy Score -> ",accuracy_score(predictions_stack_test, test_Y)*100)
# Out:
# Stacked Model Accuracy Score ->  97.68501640539556

# %%
train_accuracies = ['Train', accuracy_NB_train, accuracy_SVM_train, accuracy_DT_train, accuracy_stack_train]
test_accuracies = ['Test', accuracy_NB_test, accuracy_SVM_test, accuracy_DT_test, accuracy_stack_test]
table = [['Data Type', 'Naive Bayes', 'SVM', 'Decision Tree', 'Stacked Model'], train_accuracies, test_accuracies]
print('Model Accuracy Scores')
print(tabulate(table, headers='firstrow', tablefmt='fancy_grid'))
# Out:
# Model Accuracy Scores
# ╒═════════════╤═══════════════╤═════════╤═════════════════╤═════════════════╕
# │ Data Type   │   Naive Bayes │     SVM │   Decision Tree │   Stacked Model │
# ╞═════════════╪═══════════════╪═════════╪═════════════════╪═════════════════╡
# │ Train       │       92.6947 │ 99.1171 │        100      │         99.7422 │
# ├─────────────┼───────────────┼─────────┼─────────────────┼─────────────────┤
# │ Test        │       90.5942 │ 96.7007 │         94.0758 │         97.685  │
# ╘═════════════╧═══════════════╧═════════╧═════════════════╧═════════════════╛

# %% [markdown]
# # Making Predictive System

# %%
print("Enter a news data set number to check if the news is real or fake: ")

i = int(input())

predicted = test_X_Tfidf[i]
temp = list(test_Y)
final = temp[i]

prediction = stack_model.predict(predicted)

if (prediction[0] == 0):
  print('Prediction for news -',i,': The news is Real')
else:
  print('Prediction for news -',i,': The news is Fake')

if (final == 0):
  print('Original news -',i,': The news is Real')
else:
  print('Original news -',i,': The news is Fake')
# Out:
# Enter a news data set number to check if the news is real or fake:
# 1
# Prediction for news - 1 : The news is Fake
# Original news - 1 : The news is Fake

# %%
import copy
temp = copy.deepcopy(test_X)

# %%
s = input()
s = word_tokenize(s)
print(s)
s = lemmatize_tokens(s)
print(s)
s = [i for i in s if i not in stops and len(i) > 1]
print(s)
s = ' '.join(s)

temp[0] = s 

tf = tfidf_vect.fit_transform(temp)
print(tf[0])
a = stack_model.predict(tf[0])

if a[0] == 1:
    print('Fake')
else:
    print('Real')
# Out:
# Finance Minister Nirmala Sitharaman today said that the rupee has performed much better than other emerging market currencies. The minister's remark comes days after the rupee fell to an all-time low of 82.69. Explaining the fall, Ms Sitharaman that this was due to the dollar growing stronger. She said that the rupee was not weakening.
# ['Finance', 'Minister', 'Nirmala', 'Sitharaman', 'today', 'said', 'that', 'the', 'rupee', 'has', 'performed', 'much', 'better', 'than', 'other', 'emerging', 'market', 'currencies', '.', 'The', 'minister', "'s", 'remark', 'comes', 'days', 'after', 'the', 'rupee', 'fell', 'to', 'an', 'all-time', 'low', 'of', '82.69', '.', 'Explaining', 'the', 'fall', ',', 'Ms', 'Sitharaman', 'that', 'this', 'was', 'due', 'to', 'the', 'dollar', 'growing', 'stronger', '.', 'She', 'said', 'that', 'the', 'rupee', 'was', 'not', 'weakening', '.']
# ['Finance', 'Minister', 'Nirmala', 'Sitharaman', 'today', 'say', 'that', 'the', 'rupee', 'have', 'perform', 'much', 'well', 'than', 'other', 'emerge', 'market', 'currency', '.', 'The', 'minister', "'s", 'remark', 'come', 'day', 'after', 'the', 'rupee', 'fell', 'to', 'an', 'all-time', 'low', 'of', '82.69', '.', 'Explaining', 'the', 'fall', ',', 'Ms', 'Sitharaman', 'that', 'this', 'be', 'due', 'to', 'the', 'dollar', 'grow', 'strong', '.', 'She', 'say', 'that', 'the', 'rupee', 'be', 'not', 'weaken', '.']
# ['Finance', 'Minister', 'Nirmala', 'Sitharaman', 'today', 'say', 'rupee', 'perform', 'much', 'well', 'emerge', 'market', 'currency', 'The', 'minister', "'s", 'remark', 'come', 'day', 'rupee', 'fell', 'all-time', 'low', '82.69', 'Explaining', 'fall', 'Ms', 'Sitharaman', 'due', 'dollar', 'grow', 'strong', 'She', 'say', 'rupee', 'weaken']
#   (0, 953)	0.021103832418441312
#   (0, 2203)	0.029660456270005436
#   (0, 4193)	0.023827110116773704
#   (0, 1835)	0.03213193801680958
#   (0, 1860)	0.01927385474712488
#   (0, 4273)	0.024549438512143668
#   (0, 3809)	0.025862769100219243
#   (0, 285)	0.02226923057843019
#   (0, 75)	0.03971752239769997
#   (0, 1125)	0.02963696130595291
#   (0, 2982)	0.017906718154237642
#   (0, 2816)	0.025332159244035823
#   (0, 3124)	0.020021768185578583
#   (0, 1589)	0.026573374154155036
#   (0, 3114)	0.02279683270181506
#   (0, 3812)	0.036362337486058584
#   (0, 1619)	0.02381599152148479
#   (0, 3408)	0.019746809316803532
#   (0, 1374)	0.03782699633433042
#   (0, 690)	0.030825854429994314
#   (0, 338)	0.025345669350939685
#   (0, 4531)	0.02519833164435832
#   (0, 1193)	0.02519833164435832
#   (0, 4041)	0.019629095620076052
#   (0, 4469)	0.015108983171405983
#   :	:
#   (0, 1784)	0.06332331979585183
#   (0, 1821)	0.042085962929962265
#   (0, 2105)	0.22805147057904981
#   (0, 4357)	0.04112044849470131
#   (0, 4010)	0.061816547957514664
#   (0, 543)	0.05042128652011803
#   (0, 3451)	0.060106297065550866
#   (0, 4546)	0.10115640459766766
#   (0, 4081)	0.05149603645268824
#   (0, 1469)	0.02691311662977378
#   (0, 909)	0.04069877929654622
#   (0, 2954)	0.18027808163443415
#   (0, 1891)	0.09582121811117339
#   (0, 3171)	0.04592725516186118
#   (0, 4432)	0.049701146693842214
#   (0, 446)	0.04854720361111132
#   (0, 3125)	0.07488926505808075
#   (0, 983)	0.11451048256535164
#   (0, 4989)	0.02294444118819297
#   (0, 723)	0.02123832613061019
#   (0, 222)	0.13626507700900178
#   (0, 4524)	0.097897340671109
#   (0, 237)	0.02109599288614664
#   (0, 4978)	0.036588109081703554
#   (0, 66)	0.03242836775625941
# Fake

# %%
s = input()
s = word_tokenize(s)
s = lemmatize_tokens(s)
s = [i for i in s if i not in stops and len(i) > 1]
s = ' '.join(s)

temp[0] = s 

tf = tfidf_vect.fit_transform(temp)

a = stack_model.predict(tf[0])

if a[0] == 1:
    print('Fake')
else:
    print('Real')
# Out:
# Finance Minister Nirmala Sitharaman today said that the rupee has performed much better than other emerging market currencies. The minister's remark comes days after the rupee fell to an all-time low of 82.69. Explaining the fall, Ms Sitharaman that this was due to the dollar growing stronger. She said that the rupee was not weakening.
# Fake
